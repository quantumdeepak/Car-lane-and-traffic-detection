# %% [markdown]
# ### Lane detection and car detection
#
#
# *   This code performs lane detection and object detection (car detection) on a video.
#
# *  Lane Detection: Identifies lanes using edge detection (Canny), masking a region of interest, and finding lines using the Hough Line Transformation.
# * Car Detection: Uses a pre-trained YOLOv8 model to detect cars in the video frame.
# * Distance estimation is also calculated for each detected car using its bounding box dimensions.

# %% [markdown]
# ### Install the required liberary

# %%
# !pip install opencv-python-headless numpy ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 33.1 MB/s eta 0:00:00

# %%
import cv2
import numpy as np
import math
import time
from ultralytics import YOLO  # YOLOv8 module

# Configurable Parameters
CONFIG = {
    "input_video_path": "/content/car.mp4",  # Input video file path
    "output_video_path": "/content/test_1/detected_video.mp4",  # Output video file path
    "weights_path": "weights/yolov8n.pt",  # YOLOv8 weights file
    "frame_width": 1280,  # Output video width
    "frame_height": 720,  # Output video height
    "target_fps": 30,  # Target frames per second
    "lane_detection_canny_thresholds": (100, 200),  # Canny edge thresholds
    "lane_detection_hough_params": {
        "rho": 6,
        "theta": np.pi / 60,
        "threshold": 160,
        "min_line_length": 40,
        "max_line_gap": 25
    },
    "car_detection_confidence_threshold": 0.5  # Minimum confidence for car detection
}

# Function to mask out the region of interest
def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    match_mask_color = 255
    cv2.fillPoly(mask, vertices, match_mask_color)
    return cv2.bitwise_and(img, mask)

# Function to draw the filled polygon between the lane lines
def draw_lane_lines(img, left_line, right_line, color=[0, 255, 0], thickness=10):
    line_img = np.zeros_like(img)

    # Validate left_line and right_line
    if all(v == 0 for v in left_line) or all(v == 0 for v in right_line):
        # If either line is invalid, skip drawing
        return img

    # Create the polygon points
    poly_pts = np.array([[
        (left_line[0], left_line[1]),  # Bottom-left
        (left_line[2], left_line[3]),  # Top-left
        (right_line[2], right_line[3]),  # Top-right
        (right_line[0], right_line[1])  # Bottom-right
    ]], dtype=np.int32)

    # Ensure the polygon points are valid
    if poly_pts.shape[1] < 4:  # A valid polygon requires at least 4 points
        return img

    # Fill the polygon
    cv2.fillPoly(line_img, poly_pts, color)
    return cv2.addWeighted(img, 0.8, line_img, 0.5, 0.0)


# Lane detection pipeline
def pipeline(image, config):
    height, width = image.shape[:2]
    region_of_interest_vertices = [
        (0, height),
        (width / 2, height / 2),
        (width, height),
    ]

    # Convert to grayscale and apply Canny edge detection
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    cannyed_image = cv2.Canny(gray_image, *config["lane_detection_canny_thresholds"])

    # Mask out the region of interest
    cropped_image = region_of_interest(
        cannyed_image, np.array([region_of_interest_vertices], np.int32)
    )

    # Perform Hough Line Transformation to detect lines
    lines = cv2.HoughLinesP(
        cropped_image,
        rho=config["lane_detection_hough_params"]["rho"],
        theta=config["lane_detection_hough_params"]["theta"],
        threshold=config["lane_detection_hough_params"]["threshold"],
        minLineLength=config["lane_detection_hough_params"]["min_line_length"],
        maxLineGap=config["lane_detection_hough_params"]["max_line_gap"]
    )

    if lines is None:
        return image

    # Separate left and right lines
    left_line_x, left_line_y, right_line_x, right_line_y = [], [], [], []
    for line in lines:
        for x1, y1, x2, y2 in line:
            slope = (y2 - y1) / (x2 - x1) if (x2 - x1) != 0 else 0
            if math.fabs(slope) < 0.5:  # Ignore horizontal lines
                continue
            if slope <= 0:  # Left lane
                left_line_x.extend([x1, x2])
                left_line_y.extend([y1, y2])
            else:  # Right lane
                right_line_x.extend([x1, x2])
                right_line_y.extend([y1, y2])

    min_y, max_y = int(height * 3 / 5), height
    left_line = (
        [int(np.poly1d(np.polyfit(left_line_y, left_line_x, 1))(max_y)), max_y,
         int(np.poly1d(np.polyfit(left_line_y, left_line_x, 1))(min_y)), min_y]
        if left_line_x else [0, max_y, 0, min_y]
    )
    right_line = (
        [int(np.poly1d(np.polyfit(right_line_y, right_line_x, 1))(max_y)), max_y,
         int(np.poly1d(np.polyfit(right_line_y, right_line_x, 1))(min_y)), min_y]
        if right_line_x else [0, max_y, 0, min_y]
    )
    return draw_lane_lines(image, left_line, right_line)

# Function to estimate distance based on bounding box size
def estimate_distance(bbox_width):
    focal_length = 1000  # Example focal length, adjust as necessary
    known_width = 2.0  # Approximate car width in meters
    return (known_width * focal_length) / bbox_width

# Main function to process video
def process_video(config):
    model = YOLO(config["weights_path"])
    cap = cv2.VideoCapture(config["input_video_path"])

    if not cap.isOpened():
        print("Error: Unable to open video file.")
        return

    # Set up video writer
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(
        config["output_video_path"],
        fourcc,
        config["target_fps"],
        (config["frame_width"], config["frame_height"])
    )

    frame_time = 1.0 / config["target_fps"]

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        resized_frame = cv2.resize(frame, (config["frame_width"], config["frame_height"]))
        lane_frame = pipeline(resized_frame, config)
        results = model(resized_frame)

        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = box.conf[0]
                cls = int(box.cls[0])
                if model.names[cls] == "car" and conf >= config["car_detection_confidence_threshold"]:
                    cv2.rectangle(lane_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
                    bbox_width = x2 - x1
                    distance = estimate_distance(bbox_width)
                    cv2.putText(lane_frame, f'Distance: {distance:.2f}m', (x1, y2 + 20),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        out.write(lane_frame)
        cv2.imshow("Lane and Car Detection", lane_frame)
        time.sleep(frame_time)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
# Run the video processing function
# process_video(CONFIG)

# %% [markdown]
# #### This is not working as cv2.imshow dot work in colab notebook

# %%
import cv2
import numpy as np
import math
import time
from ultralytics import YOLO  # YOLOv8 module

# Configuration variables
CONFIG = {
    "input_video": "/content/car.mp4",       # Path to the input video
    "output_video": "/content/test_1/output.mp4",   # Path to save the processed video
    "weights": "weights/yolov8n.pt",       # YOLO model weights
    "output_resolution": (1280, 720),      # Output resolution (width, height)
    "fps": 30,                             # Frames per second for output video
    "confidence_threshold": 0.5,           # Minimum confidence to display bounding boxes
    "known_width": 2.0,                    # Approximate car width in meters
    "focal_length": 1000,                  # Focal length for distance estimation
}

# Function to mask out the region of interest
def region_of_interest(img, vertices):
    mask = np.zeros_like(img)
    match_mask_color = 255
    cv2.fillPoly(mask, vertices, match_mask_color)
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

# Function to draw the filled polygon between the lane lines
def draw_lane_lines(img, left_line, right_line, color=[0, 255, 0], thickness=10):
    line_img = np.zeros_like(img)
    if all(v == 0 for v in left_line) or all(v == 0 for v in right_line):
        return img

    poly_pts = np.array([[
        (left_line[0], left_line[1]),
        (left_line[2], left_line[3]),
        (right_line[2], right_line[3]),
        (right_line[0], right_line[1])
    ]], dtype=np.int32)

    if poly_pts.shape[1] < 4:
        return img

    cv2.fillPoly(line_img, poly_pts, color)
    return cv2.addWeighted(img, 0.8, line_img, 0.5, 0.0)

# The lane detection pipeline
def pipeline(image):
    height, width = image.shape[:2]
    region_of_interest_vertices = [
        (0, height),
        (width / 2, height / 2),
        (width, height),
    ]

    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    cannyed_image = cv2.Canny(gray_image, 100, 200)
    cropped_image = region_of_interest(cannyed_image, np.array([region_of_interest_vertices], np.int32))

    lines = cv2.HoughLinesP(
        cropped_image, rho=6, theta=np.pi / 60, threshold=160,
        lines=np.array([]), minLineLength=40, maxLineGap=25
    )

    left_line_x, left_line_y, right_line_x, right_line_y = [], [], [], []

    if lines is None:
        return image

    for line in lines:
        for x1, y1, x2, y2 in line:
            slope = (y2 - y1) / (x2 - x1) if (x2 - x1) != 0 else 0
            if math.fabs(slope) < 0.5:
                continue
            if slope <= 0:
                left_line_x.extend([x1, x2])
                left_line_y.extend([y1, y2])
            else:
                right_line_x.extend([x1, x2])
                right_line_y.extend([y1, y2])

    min_y = int(height * (3 / 5))
    max_y = height

    left_x_start, left_x_end, right_x_start, right_x_end = 0, 0, 0, 0
    if left_line_x and left_line_y:
        poly_left = np.poly1d(np.polyfit(left_line_y, left_line_x, deg=1))
        left_x_start, left_x_end = int(poly_left(max_y)), int(poly_left(min_y))

    if right_line_x and right_line_y:
        poly_right = np.poly1d(np.polyfit(right_line_y, right_line_x, deg=1))
        right_x_start, right_x_end = int(poly_right(max_y)), int(poly_right(min_y))

    return draw_lane_lines(image, [left_x_start, max_y, left_x_end, min_y], [right_x_start, max_y, right_x_end, min_y])

# Function to estimate distance based on bounding box size
def estimate_distance(bbox_width, bbox_height, config):
    known_width = config["known_width"]
    focal_length = config["focal_length"]
    return (known_width * focal_length) / bbox_width if bbox_width else 0

# Main function to read and process video with YOLOv8
def process_video(config):
    model = YOLO(config["weights"])
    cap = cv2.VideoCapture(config["input_video"])

    if not cap.isOpened():
        print("Error: Unable to open video file.")
        return

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(config["output_video"], fourcc, config["fps"], config["output_resolution"])

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        resized_frame = cv2.resize(frame, config["output_resolution"])
        lane_frame = pipeline(resized_frame)
        results = model(resized_frame)

        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = box.conf[0]
                cls = int(box.cls[0])

                if model.names[cls] == 'car' and conf >= config["confidence_threshold"]:
                    label = f'{model.names[cls]} {conf:.2f}'
                    cv2.rectangle(lane_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
                    cv2.putText(lane_frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
                    distance = estimate_distance(x2 - x1, y2 - y1, config)
                    distance_label = f'Distance: {distance:.2f}m'
                    cv2.putText(lane_frame, distance_label, (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        out.write(lane_frame)

    cap.release()
    out.release()
    print(f"Processed video saved at {config['output_video']}")

# Run the video processing function
process_video(CONFIG)
# Out:
# 0: 384x640 6 cars, 161.0ms
# Speed: 2.5ms preprocess, 161.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 166.7ms
# Speed: 3.0ms preprocess, 166.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 146.2ms
# Speed: 2.7ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 166.9ms
# Speed: 3.4ms preprocess, 166.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 154.9ms
# Speed: 2.6ms preprocess, 154.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 144.3ms
# Speed: 2.9ms preprocess, 144.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 172.1ms
# Speed: 2.6ms preprocess, 172.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 143.3ms
# Speed: 4.1ms preprocess, 143.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 169.2ms
# Speed: 2.9ms preprocess, 169.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 145.1ms
# Speed: 4.3ms preprocess, 145.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 146.5ms
# Speed: 2.9ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 154.3ms
# Speed: 3.2ms preprocess, 154.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.4ms
# Speed: 3.5ms preprocess, 162.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 155.1ms
# Speed: 2.7ms preprocess, 155.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 145.2ms
# Speed: 2.6ms preprocess, 145.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 146.1ms
# Speed: 2.6ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 157.2ms
# Speed: 2.7ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 149.2ms
# Speed: 3.6ms preprocess, 149.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 152.5ms
# Speed: 2.6ms preprocess, 152.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 155.4ms
# Speed: 2.7ms preprocess, 155.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 148.7ms
# Speed: 3.9ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 148.9ms
# Speed: 2.6ms preprocess, 148.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 166.1ms
# Speed: 3.6ms preprocess, 166.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 148.0ms
# Speed: 2.6ms preprocess, 148.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 166.8ms
# Speed: 2.6ms preprocess, 166.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 180.1ms
# Speed: 3.4ms preprocess, 180.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 253.0ms
# Speed: 2.7ms preprocess, 253.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 225.9ms
# Speed: 3.2ms preprocess, 225.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 238.6ms
# Speed: 2.8ms preprocess, 238.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 222.7ms
# Speed: 2.7ms preprocess, 222.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 241.6ms
# Speed: 2.7ms preprocess, 241.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 220.5ms
# Speed: 2.7ms preprocess, 220.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 252.4ms
# Speed: 4.7ms preprocess, 252.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 245.7ms
# Speed: 4.6ms preprocess, 245.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 238.9ms
# Speed: 2.8ms preprocess, 238.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 252.9ms
# Speed: 2.6ms preprocess, 252.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 252.7ms
# Speed: 2.8ms preprocess, 252.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 150.1ms
# Speed: 3.5ms preprocess, 150.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 147.6ms
# Speed: 2.8ms preprocess, 147.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 150.4ms
# Speed: 3.9ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 160.2ms
# Speed: 2.6ms preprocess, 160.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 172.7ms
# Speed: 4.3ms preprocess, 172.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 147.0ms
# Speed: 2.8ms preprocess, 147.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 154.3ms
# Speed: 2.9ms preprocess, 154.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 157.1ms
# Speed: 2.7ms preprocess, 157.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 149.3ms
# Speed: 2.7ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 164.9ms
# Speed: 2.5ms preprocess, 164.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 158.3ms
# Speed: 3.5ms preprocess, 158.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 147.4ms
# Speed: 4.2ms preprocess, 147.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 151.2ms
# Speed: 4.2ms preprocess, 151.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.1ms
# Speed: 4.1ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 171.2ms
# Speed: 3.0ms preprocess, 171.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 144.2ms
# Speed: 2.9ms preprocess, 144.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 158.0ms
# Speed: 2.7ms preprocess, 158.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 140.2ms
# Speed: 2.6ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 173.0ms
# Speed: 2.6ms preprocess, 173.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 171.7ms
# Speed: 2.7ms preprocess, 171.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 149.1ms
# Speed: 2.7ms preprocess, 149.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.5ms
# Speed: 4.0ms preprocess, 146.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 149.2ms
# Speed: 3.5ms preprocess, 149.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 158.5ms
# Speed: 2.9ms preprocess, 158.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 171.0ms
# Speed: 4.1ms preprocess, 171.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 148.5ms
# Speed: 5.9ms preprocess, 148.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 156.3ms
# Speed: 3.5ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.7ms
# Speed: 4.1ms preprocess, 146.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 161.2ms
# Speed: 2.8ms preprocess, 161.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 160.0ms
# Speed: 3.7ms preprocess, 160.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 154.7ms
# Speed: 2.6ms preprocess, 154.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 145.4ms
# Speed: 2.7ms preprocess, 145.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.6ms
# Speed: 3.1ms preprocess, 155.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 145.1ms
# Speed: 2.7ms preprocess, 145.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 174.2ms
# Speed: 3.8ms preprocess, 174.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 148.7ms
# Speed: 3.0ms preprocess, 148.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 155.8ms
# Speed: 4.0ms preprocess, 155.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 145.3ms
# Speed: 3.4ms preprocess, 145.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 160.2ms
# Speed: 2.6ms preprocess, 160.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 157.4ms
# Speed: 3.5ms preprocess, 157.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 188.5ms
# Speed: 4.3ms preprocess, 188.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 148.8ms
# Speed: 2.7ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 152.8ms
# Speed: 3.3ms preprocess, 152.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 144.7ms
# Speed: 2.6ms preprocess, 144.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 163.9ms
# Speed: 2.7ms preprocess, 163.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 166.5ms
# Speed: 4.3ms preprocess, 166.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 158.0ms
# Speed: 2.6ms preprocess, 158.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 143.9ms
# Speed: 2.7ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 149.2ms
# Speed: 2.5ms preprocess, 149.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 149.8ms
# Speed: 4.2ms preprocess, 149.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 230.1ms
# Speed: 4.2ms preprocess, 230.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 231.0ms
# Speed: 3.6ms preprocess, 231.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 233.4ms
# Speed: 4.3ms preprocess, 233.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 237.5ms
# Speed: 3.3ms preprocess, 237.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 225.4ms
# Speed: 4.0ms preprocess, 225.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 225.6ms
# Speed: 3.0ms preprocess, 225.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 237.6ms
# Speed: 3.1ms preprocess, 237.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 248.8ms
# Speed: 3.4ms preprocess, 248.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 250.6ms
# Speed: 5.6ms preprocess, 250.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 230.1ms
# Speed: 2.8ms preprocess, 230.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 252.8ms
# Speed: 2.8ms preprocess, 252.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 229.6ms
# Speed: 2.7ms preprocess, 229.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 173.4ms
# Speed: 3.2ms preprocess, 173.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 145.2ms
# Speed: 3.4ms preprocess, 145.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 156.8ms
# Speed: 2.8ms preprocess, 156.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 159.3ms
# Speed: 5.1ms preprocess, 159.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 152.8ms
# Speed: 2.5ms preprocess, 152.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 145.2ms
# Speed: 4.2ms preprocess, 145.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 156.4ms
# Speed: 4.0ms preprocess, 156.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 141.5ms
# Speed: 2.6ms preprocess, 141.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 180.3ms
# Speed: 2.8ms preprocess, 180.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 153.6ms
# Speed: 3.5ms preprocess, 153.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 157.4ms
# Speed: 2.6ms preprocess, 157.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 143.6ms
# Speed: 3.4ms preprocess, 143.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 144.5ms
# Speed: 3.3ms preprocess, 144.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 162.3ms
# Speed: 3.3ms preprocess, 162.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 154.6ms
# Speed: 6.0ms preprocess, 154.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 151.1ms
# Speed: 2.7ms preprocess, 151.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 148.0ms
# Speed: 2.7ms preprocess, 148.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 155.5ms
# Speed: 2.5ms preprocess, 155.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 162.6ms
# Speed: 4.2ms preprocess, 162.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 155.9ms
# Speed: 3.6ms preprocess, 155.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 146.2ms
# Speed: 4.2ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 151.2ms
# Speed: 4.3ms preprocess, 151.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 141.8ms
# Speed: 3.6ms preprocess, 141.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 148.7ms
# Speed: 3.9ms preprocess, 148.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 146.2ms
# Speed: 4.6ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 151.4ms
# Speed: 3.6ms preprocess, 151.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 152.5ms
# Speed: 3.2ms preprocess, 152.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 136.9ms
# Speed: 2.6ms preprocess, 136.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 145.6ms
# Speed: 2.6ms preprocess, 145.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 161.2ms
# Speed: 2.8ms preprocess, 161.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 150.3ms
# Speed: 2.6ms preprocess, 150.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 147.6ms
# Speed: 3.4ms preprocess, 147.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 148.3ms
# Speed: 2.6ms preprocess, 148.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 144.1ms
# Speed: 2.2ms preprocess, 144.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 169.0ms
# Speed: 4.4ms preprocess, 169.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 141.9ms
# Speed: 4.1ms preprocess, 141.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 159.3ms
# Speed: 5.3ms preprocess, 159.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 143.8ms
# Speed: 3.3ms preprocess, 143.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 151.3ms
# Speed: 3.2ms preprocess, 151.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 167.6ms
# Speed: 2.8ms preprocess, 167.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 151.5ms
# Speed: 3.8ms preprocess, 151.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 156.9ms
# Speed: 2.9ms preprocess, 156.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 155.3ms
# Speed: 2.6ms preprocess, 155.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 139.9ms
# Speed: 4.2ms preprocess, 139.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 168.3ms
# Speed: 3.9ms preprocess, 168.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 146.1ms
# Speed: 3.4ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 156.9ms
# Speed: 2.6ms preprocess, 156.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 146.7ms
# Speed: 2.8ms preprocess, 146.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 149.7ms
# Speed: 4.6ms preprocess, 149.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 145.3ms
# Speed: 4.4ms preprocess, 145.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 163.9ms
# Speed: 3.6ms preprocess, 163.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 147.3ms
# Speed: 2.7ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 209.7ms
# Speed: 2.3ms preprocess, 209.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 224.2ms
# Speed: 2.7ms preprocess, 224.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 240.7ms
# Speed: 2.6ms preprocess, 240.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 222.2ms
# Speed: 2.7ms preprocess, 222.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 246.2ms
# Speed: 2.6ms preprocess, 246.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 219.1ms
# Speed: 2.7ms preprocess, 219.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 236.8ms
# Speed: 3.1ms preprocess, 236.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 229.7ms
# Speed: 2.6ms preprocess, 229.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 239.1ms
# Speed: 2.6ms preprocess, 239.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 244.2ms
# Speed: 2.7ms preprocess, 244.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 238.0ms
# Speed: 3.6ms preprocess, 238.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 246.4ms
# Speed: 4.2ms preprocess, 246.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 226.6ms
# Speed: 3.1ms preprocess, 226.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 143.5ms
# Speed: 3.1ms preprocess, 143.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 149.4ms
# Speed: 2.6ms preprocess, 149.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 146.4ms
# Speed: 2.6ms preprocess, 146.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 165.3ms
# Speed: 2.5ms preprocess, 165.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 155.1ms
# Speed: 2.6ms preprocess, 155.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 162.8ms
# Speed: 3.0ms preprocess, 162.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 140.7ms
# Speed: 2.5ms preprocess, 140.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 150.5ms
# Speed: 2.6ms preprocess, 150.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 152.3ms
# Speed: 2.6ms preprocess, 152.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 154.7ms
# Speed: 3.0ms preprocess, 154.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 161.5ms
# Speed: 2.7ms preprocess, 161.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 3 traffic lights, 151.6ms
# Speed: 2.7ms preprocess, 151.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 traffic lights, 147.3ms
# Speed: 2.5ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 traffic lights, 158.0ms
# Speed: 2.5ms preprocess, 158.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 142.4ms
# Speed: 3.2ms preprocess, 142.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 168.1ms
# Speed: 3.2ms preprocess, 168.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 2 traffic lights, 154.2ms
# Speed: 2.6ms preprocess, 154.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 3 traffic lights, 148.6ms
# Speed: 2.6ms preprocess, 148.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 143.9ms
# Speed: 4.2ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 168.4ms
# Speed: 2.5ms preprocess, 168.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 162.6ms
# Speed: 2.9ms preprocess, 162.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 150.0ms
# Speed: 3.3ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 3 traffic lights, 139.3ms
# Speed: 3.9ms preprocess, 139.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 traffic lights, 150.3ms
# Speed: 2.9ms preprocess, 150.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 traffic lights, 160.8ms
# Speed: 3.2ms preprocess, 160.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 traffic lights, 181.8ms
# Speed: 2.6ms preprocess, 181.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 traffic lights, 147.0ms
# Speed: 2.7ms preprocess, 147.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 traffic lights, 152.8ms
# Speed: 2.6ms preprocess, 152.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 144.5ms
# Speed: 2.8ms preprocess, 144.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 traffic lights, 157.4ms
# Speed: 3.6ms preprocess, 157.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 3 traffic lights, 171.8ms
# Speed: 2.6ms preprocess, 171.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 3 traffic lights, 156.5ms
# Speed: 4.6ms preprocess, 156.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 4 traffic lights, 142.2ms
# Speed: 2.8ms preprocess, 142.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 4 traffic lights, 154.8ms
# Speed: 2.7ms preprocess, 154.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 traffic lights, 141.0ms
# Speed: 4.3ms preprocess, 141.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 traffic lights, 175.2ms
# Speed: 2.9ms preprocess, 175.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 traffic lights, 144.6ms
# Speed: 2.7ms preprocess, 144.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 151.2ms
# Speed: 2.7ms preprocess, 151.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 traffic lights, 144.0ms
# Speed: 3.7ms preprocess, 144.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 traffic lights, 151.2ms
# Speed: 4.3ms preprocess, 151.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 traffic lights, 173.6ms
# Speed: 2.6ms preprocess, 173.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 156.1ms
# Speed: 2.9ms preprocess, 156.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 4 traffic lights, 152.6ms
# Speed: 2.9ms preprocess, 152.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 147.8ms
# Speed: 2.9ms preprocess, 147.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 172.6ms
# Speed: 2.8ms preprocess, 172.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 147.5ms
# Speed: 5.0ms preprocess, 147.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 5 traffic lights, 156.0ms
# Speed: 3.6ms preprocess, 156.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 5 traffic lights, 147.1ms
# Speed: 3.7ms preprocess, 147.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 traffic lights, 156.1ms
# Speed: 3.2ms preprocess, 156.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 traffic lights, 168.6ms
# Speed: 2.5ms preprocess, 168.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 traffic lights, 253.2ms
# Speed: 2.7ms preprocess, 253.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 7 traffic lights, 225.2ms
# Speed: 3.5ms preprocess, 225.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 6 traffic lights, 231.9ms
# Speed: 3.7ms preprocess, 231.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 4 traffic lights, 252.6ms
# Speed: 3.3ms preprocess, 252.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 226.8ms
# Speed: 2.7ms preprocess, 226.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 227.2ms
# Speed: 3.0ms preprocess, 227.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 262.6ms
# Speed: 2.9ms preprocess, 262.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 5 traffic lights, 229.3ms
# Speed: 2.8ms preprocess, 229.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 6 traffic lights, 251.3ms
# Speed: 4.6ms preprocess, 251.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 7 traffic lights, 443.0ms
# Speed: 2.6ms preprocess, 443.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 7 traffic lights, 554.0ms
# Speed: 2.9ms preprocess, 554.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 249.3ms
# Speed: 2.9ms preprocess, 249.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 3 traffic lights, 166.9ms
# Speed: 2.7ms preprocess, 166.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 3 traffic lights, 230.2ms
# Speed: 3.2ms preprocess, 230.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 3 traffic lights, 298.0ms
# Speed: 3.2ms preprocess, 298.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 3 traffic lights, 168.0ms
# Speed: 3.3ms preprocess, 168.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 3 traffic lights, 161.4ms
# Speed: 2.6ms preprocess, 161.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 3 traffic lights, 144.3ms
# Speed: 2.6ms preprocess, 144.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 3 traffic lights, 149.8ms
# Speed: 2.7ms preprocess, 149.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 3 traffic lights, 170.2ms
# Speed: 4.0ms preprocess, 170.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 4 traffic lights, 156.8ms
# Speed: 4.1ms preprocess, 156.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 4 traffic lights, 143.7ms
# Speed: 3.2ms preprocess, 143.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 3 traffic lights, 151.5ms
# Speed: 4.6ms preprocess, 151.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 3 traffic lights, 141.8ms
# Speed: 4.7ms preprocess, 141.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 3 traffic lights, 166.9ms
# Speed: 4.3ms preprocess, 166.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 3 traffic lights, 146.5ms
# Speed: 4.3ms preprocess, 146.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 3 traffic lights, 164.4ms
# Speed: 3.3ms preprocess, 164.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 traffic lights, 150.9ms
# Speed: 2.6ms preprocess, 150.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 155.7ms
# Speed: 2.6ms preprocess, 155.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 traffic lights, 185.1ms
# Speed: 2.6ms preprocess, 185.1ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 192.4ms
# Speed: 2.7ms preprocess, 192.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 3 traffic lights, 146.7ms
# Speed: 3.0ms preprocess, 146.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 162.8ms
# Speed: 3.0ms preprocess, 162.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 151.7ms
# Speed: 3.0ms preprocess, 151.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 traffic lights, 224.0ms
# Speed: 5.0ms preprocess, 224.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 3 traffic lights, 257.4ms
# Speed: 3.1ms preprocess, 257.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 3 traffic lights, 181.8ms
# Speed: 4.8ms preprocess, 181.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 traffic lights, 158.3ms
# Speed: 3.0ms preprocess, 158.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 traffic lights, 190.0ms
# Speed: 9.6ms preprocess, 190.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 159.3ms
# Speed: 4.2ms preprocess, 159.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 248.8ms
# Speed: 4.3ms preprocess, 248.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 314.1ms
# Speed: 6.0ms preprocess, 314.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 157.9ms
# Speed: 4.6ms preprocess, 157.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 155.3ms
# Speed: 3.8ms preprocess, 155.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 157.2ms
# Speed: 2.7ms preprocess, 157.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 187.9ms
# Speed: 3.7ms preprocess, 187.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 293.3ms
# Speed: 3.4ms preprocess, 293.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 154.2ms
# Speed: 4.3ms preprocess, 154.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 158.6ms
# Speed: 3.7ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 4 traffic lights, 147.3ms
# Speed: 2.7ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 169.9ms
# Speed: 2.6ms preprocess, 169.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 148.8ms
# Speed: 2.6ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 290.8ms
# Speed: 2.6ms preprocess, 290.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 257.9ms
# Speed: 3.9ms preprocess, 257.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 379.0ms
# Speed: 2.8ms preprocess, 379.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 880.7ms
# Speed: 3.1ms preprocess, 880.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 airplane, 1 truck, 4 traffic lights, 265.9ms
# Speed: 2.7ms preprocess, 265.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 242.2ms
# Speed: 2.9ms preprocess, 242.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 airplane, 1 truck, 4 traffic lights, 243.3ms
# Speed: 2.9ms preprocess, 243.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 4 traffic lights, 241.0ms
# Speed: 2.9ms preprocess, 241.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 4 traffic lights, 273.9ms
# Speed: 2.8ms preprocess, 273.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 229.0ms
# Speed: 2.8ms preprocess, 229.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 153.3ms
# Speed: 2.6ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 4 traffic lights, 141.6ms
# Speed: 4.2ms preprocess, 141.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 4 traffic lights, 166.7ms
# Speed: 2.6ms preprocess, 166.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 3 traffic lights, 160.5ms
# Speed: 2.6ms preprocess, 160.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 3 traffic lights, 158.3ms
# Speed: 2.6ms preprocess, 158.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 3 traffic lights, 146.0ms
# Speed: 3.5ms preprocess, 146.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 3 traffic lights, 156.9ms
# Speed: 2.6ms preprocess, 156.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 3 traffic lights, 153.3ms
# Speed: 2.7ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 traffic lights, 170.6ms
# Speed: 2.9ms preprocess, 170.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 145.9ms
# Speed: 2.6ms preprocess, 145.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 157.8ms
# Speed: 2.6ms preprocess, 157.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 148.5ms
# Speed: 2.6ms preprocess, 148.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 5 traffic lights, 166.1ms
# Speed: 2.9ms preprocess, 166.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 160.0ms
# Speed: 2.8ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 153.7ms
# Speed: 2.8ms preprocess, 153.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 143.7ms
# Speed: 2.7ms preprocess, 143.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 149.0ms
# Speed: 2.5ms preprocess, 149.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 143.9ms
# Speed: 2.9ms preprocess, 143.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 169.8ms
# Speed: 2.7ms preprocess, 169.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 143.9ms
# Speed: 4.2ms preprocess, 143.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 traffic lights, 149.7ms
# Speed: 2.9ms preprocess, 149.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 traffic lights, 138.9ms
# Speed: 2.8ms preprocess, 138.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 traffic lights, 149.1ms
# Speed: 3.7ms preprocess, 149.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 traffic lights, 164.4ms
# Speed: 3.0ms preprocess, 164.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 traffic lights, 156.0ms
# Speed: 4.8ms preprocess, 156.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 traffic lights, 148.4ms
# Speed: 4.0ms preprocess, 148.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 traffic lights, 159.0ms
# Speed: 2.6ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 traffic lights, 144.0ms
# Speed: 2.7ms preprocess, 144.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 traffic lights, 158.2ms
# Speed: 2.6ms preprocess, 158.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 traffic lights, 148.1ms
# Speed: 6.0ms preprocess, 148.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 traffic lights, 148.9ms
# Speed: 4.0ms preprocess, 148.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 traffic lights, 157.8ms
# Speed: 3.9ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 traffic lights, 154.3ms
# Speed: 5.4ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 traffic lights, 174.2ms
# Speed: 3.5ms preprocess, 174.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 6 traffic lights, 164.0ms
# Speed: 3.1ms preprocess, 164.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 170.3ms
# Speed: 6.1ms preprocess, 170.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7 traffic lights, 154.9ms
# Speed: 3.4ms preprocess, 154.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7 traffic lights, 156.1ms
# Speed: 3.4ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 7 traffic lights, 176.9ms
# Speed: 3.5ms preprocess, 176.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 6 traffic lights, 174.3ms
# Speed: 2.7ms preprocess, 174.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 6 traffic lights, 164.7ms
# Speed: 2.8ms preprocess, 164.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 6 traffic lights, 183.1ms
# Speed: 4.8ms preprocess, 183.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 6 traffic lights, 163.7ms
# Speed: 3.2ms preprocess, 163.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 6 traffic lights, 204.1ms
# Speed: 3.1ms preprocess, 204.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 157.4ms
# Speed: 3.1ms preprocess, 157.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 166.8ms
# Speed: 3.2ms preprocess, 166.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 157.9ms
# Speed: 2.7ms preprocess, 157.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 170.1ms
# Speed: 3.5ms preprocess, 170.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 184.9ms
# Speed: 3.4ms preprocess, 184.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 5 traffic lights, 228.9ms
# Speed: 4.4ms preprocess, 228.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 240.5ms
# Speed: 3.7ms preprocess, 240.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 243.9ms
# Speed: 3.8ms preprocess, 243.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 244.7ms
# Speed: 2.8ms preprocess, 244.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 233.8ms
# Speed: 2.7ms preprocess, 233.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 217.3ms
# Speed: 3.6ms preprocess, 217.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 243.0ms
# Speed: 6.1ms preprocess, 243.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 236.8ms
# Speed: 2.7ms preprocess, 236.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 243.1ms
# Speed: 2.7ms preprocess, 243.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 231.4ms
# Speed: 2.6ms preprocess, 231.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 4 traffic lights, 255.0ms
# Speed: 2.8ms preprocess, 255.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 237.4ms
# Speed: 2.6ms preprocess, 237.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 150.8ms
# Speed: 3.3ms preprocess, 150.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 163.2ms
# Speed: 3.2ms preprocess, 163.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 141.7ms
# Speed: 4.3ms preprocess, 141.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 156.3ms
# Speed: 2.7ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 143.6ms
# Speed: 2.7ms preprocess, 143.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 4 traffic lights, 177.4ms
# Speed: 3.1ms preprocess, 177.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 158.6ms
# Speed: 4.6ms preprocess, 158.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 159.2ms
# Speed: 2.7ms preprocess, 159.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 145.0ms
# Speed: 2.6ms preprocess, 145.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 4 traffic lights, 153.0ms
# Speed: 2.6ms preprocess, 153.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 4 traffic lights, 162.2ms
# Speed: 4.2ms preprocess, 162.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 156.0ms
# Speed: 4.4ms preprocess, 156.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 4 traffic lights, 145.8ms
# Speed: 4.0ms preprocess, 145.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 161.0ms
# Speed: 2.8ms preprocess, 161.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 144.2ms
# Speed: 3.5ms preprocess, 144.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 170.5ms
# Speed: 2.5ms preprocess, 170.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 146.6ms
# Speed: 3.8ms preprocess, 146.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 4 traffic lights, 159.7ms
# Speed: 6.4ms preprocess, 159.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 7 traffic lights, 155.2ms
# Speed: 2.6ms preprocess, 155.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 7 traffic lights, 164.2ms
# Speed: 5.5ms preprocess, 164.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 7 traffic lights, 164.3ms
# Speed: 3.5ms preprocess, 164.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8 traffic lights, 169.7ms
# Speed: 3.4ms preprocess, 169.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8 traffic lights, 161.4ms
# Speed: 2.9ms preprocess, 161.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8 traffic lights, 150.6ms
# Speed: 2.9ms preprocess, 150.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 7 traffic lights, 160.7ms
# Speed: 4.7ms preprocess, 160.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 6 traffic lights, 145.9ms
# Speed: 4.5ms preprocess, 145.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8 traffic lights, 169.4ms
# Speed: 2.9ms preprocess, 169.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 158.0ms
# Speed: 2.7ms preprocess, 158.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8 traffic lights, 167.2ms
# Speed: 3.1ms preprocess, 167.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 148.3ms
# Speed: 4.3ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 153.4ms
# Speed: 4.1ms preprocess, 153.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 157.5ms
# Speed: 3.0ms preprocess, 157.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 157.2ms
# Speed: 4.6ms preprocess, 157.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 158.3ms
# Speed: 3.5ms preprocess, 158.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 166.3ms
# Speed: 5.8ms preprocess, 166.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 160.2ms
# Speed: 4.6ms preprocess, 160.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 6 traffic lights, 186.0ms
# Speed: 4.2ms preprocess, 186.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 149.9ms
# Speed: 3.4ms preprocess, 149.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 7 traffic lights, 169.1ms
# Speed: 4.1ms preprocess, 169.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 9 traffic lights, 141.2ms
# Speed: 4.5ms preprocess, 141.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9 traffic lights, 147.2ms
# Speed: 3.4ms preprocess, 147.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 8 traffic lights, 157.1ms
# Speed: 3.3ms preprocess, 157.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved at /content/test_1/output.mp4
